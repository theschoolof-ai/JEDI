# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd /content/gdrive/'My Drive'/EVA/EVA5/YoloV3_S13/YoloV3
# Out:
# /content/gdrive/My Drive/EVA/EVA5/YoloV3_S13/YoloV3

# %%
# !ls
# Out:
#  cfg		 output         runs		  'ubdivisions=1'
#  data		 __pycache__    test_batch0.png    utils
#  detect.py	 README.md      test.py		   vim.exe.stackdump
#  image_wip.csv	 results.json   ting		   weights
#  label_wip.csv	 results.png    train_batch0.png   YoLoV3_Output
#  models.py	 results.txt    train.py

# %%
# !ls 'weights'
# Out:
# yolov3-spp-ultralytics.pt

# %%
# !pwd
# Out:
# /content/YoloV3-1

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 50 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=50, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-25 06:41:11.112464: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3065 found, 139 missing, 0 empty, 0 duplicate, for 3204 images): 100% 3204/3204 [00:03<00:00, 1043.80it/s]
# Caching images (1.8GB): 100% 3204/3204 [00:28<00:00, 111.16it/s]
# ...

# %%
# !ls YoLoV3_Output

# %%
# !python detect.py --source '/content/gdrive/My Drive/EVA/EVA5/input_images_video' --conf-thres 0.3 --output YoLoV3_Output
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='YoLoV3_Output', save_txt=False, source='/content/gdrive/My Drive/EVA/EVA5/input_images_video', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/382 /content/gdrive/My Drive/EVA/EVA5/input_images_video/Copy of image-121.png: 320x512 Done. (0.033s)
# image 2/382 /content/gdrive/My Drive/EVA/EVA5/input_images_video/Copy of image-122.png: 320x512 Done. (0.033s)
# image 3/382 /content/gdrive/My Drive/EVA/EVA5/input_images_video/Copy of image-123.png: 320x512 Done. (0.024s)
# image 4/382 /content/gdrive/My Drive/EVA/EVA5/input_images_video/Copy of image-124.png: 320x512 Done. (0.024s)
# ...

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/EVA/EVA5/YoloV3_S13/YoloV3

# %%
Image(filename='YoLoV3_Output/Copy of image-134.png', width=600)
